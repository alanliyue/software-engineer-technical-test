# %% [markdown]
# # Earthquake risk in Greece
#
# This project is quite different from a software development task.
#
# Don't hesitate to contact us, if you have any doubts on what is asked or if you encounter error will using the notebook.

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Constraints
#
# + 🚨 Only cells with the comment `# NOTE: Fill me!` should be filled
# + 🚨 Notebook should be saved and commited **with** outputs for the submission
#
#
# + ⚠️ The solution only requires packages listed in the `requirements/requirements.txt`
# + ⚠️ Unit tests should be favored when asked to write tests
# + ⚠️ Tests must automatically be detected running `pytest`
# + ⚠️ Requested method signature should be inferred from this notebook
#
#
# ## Note
#
# + The `assert` statements in the notebook are here to guide the project.
# However, successful `assert` statements does not guaranty that your code is correct.
#
# ## Setup
#
# In a Python >= 3.8 virtual env, run:

# %%
! pip install -r ../requirements/requirements.txt
! pip install --no-deps -e ..
# Out:
# Collecting pandas
#   Downloading pandas-2.0.3-cp310-cp310-win_amd64.whl (10.7 MB)
#      ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#      - -------------------------------------- 0.5/10.7 MB 10.9 MB/s eta 0:00:01
#      ----- ---------------------------------- 1.5/10.7 MB 15.5 MB/s eta 0:00:01
#      --------- ------------------------------ 2.5/10.7 MB 19.9 MB/s eta 0:00:01
#      ------------ --------------------------- 3.4/10.7 MB 19.9 MB/s eta 0:00:01
#      ---------------- ----------------------- 4.4/10.7 MB 20.3 MB/s eta 0:00:01
#      ---------------------- ----------------- 5.9/10.7 MB 22.1 MB/s eta 0:00:01
#      -------------------------- ------------- 7.0/10.7 MB 22.4 MB/s eta 0:00:01
#      ------------------------------ --------- 8.2/10.7 MB 22.7 MB/s eta 0:00:01
#      ------------------------------------ --- 9.8/10.7 MB 24.2 MB/s eta 0:00:01
#      --------------------------------------  10.7/10.7 MB 25.2 MB/s eta 0:00:01
#      --------------------------------------- 10.7/10.7 MB 22.6 MB/s eta 0:00:00
# Collecting numpy
#   Downloading numpy-1.25.2-cp310-cp310-win_amd64.whl (15.6 MB)
#      ---------------------------------------- 0.0/15.6 MB ? eta -:--:--
#      --- ------------------------------------ 1.4/15.6 MB 30.3 MB/s eta 0:00:01
#      ------- -------------------------------- 3.1/15.6 MB 32.8 MB/s eta 0:00:01
#      ----------- ---------------------------- 4.6/15.6 MB 32.3 MB/s eta 0:00:01
#      --------------- ------------------------ 6.0/15.6 MB 31.8 MB/s eta 0:00:01
#      ------------------- -------------------- 7.5/15.6 MB 32.2 MB/s eta 0:00:01
#      ----------------------- ---------------- 9.2/15.6 MB 32.7 MB/s eta 0:00:01
#      -------------------------- ------------ 10.6/15.6 MB 34.4 MB/s eta 0:00:01
#      ----------------------------- --------- 11.8/15.6 MB 32.8 MB/s eta 0:00:01
#      -------------------------------- ------ 13.1/15.6 MB 31.2 MB/s eta 0:00:01
#      ------------------------------------- - 14.8/15.6 MB 31.2 MB/s eta 0:00:01
#      --------------------------------------  15.6/15.6 MB 32.8 MB/s eta 0:00:01
#      --------------------------------------  15.6/15.6 MB 32.8 MB/s eta 0:00:01
#      --------------------------------------- 15.6/15.6 MB 26.1 MB/s eta 0:00:00
# Requirement already satisfied: ipykernel in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r ../requirements/requirements.txt (line 3)) (6.25.1)
# Collecting pytest
#   Downloading pytest-7.4.0-py3-none-any.whl (323 kB)
#      ---------------------------------------- 0.0/323.6 kB ? eta -:--:--
#      ------------------------------------- 323.6/323.6 kB 20.9 MB/s eta 0:00:00
# Collecting matplotlib
#   Downloading matplotlib-3.7.2-cp310-cp310-win_amd64.whl (7.5 MB)
#      ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#      ------- -------------------------------- 1.4/7.5 MB 43.9 MB/s eta 0:00:01
#      ------------ --------------------------- 2.4/7.5 MB 30.3 MB/s eta 0:00:01
#      --------------------- ------------------ 4.0/7.5 MB 31.9 MB/s eta 0:00:01
#      -------------------------- ------------- 5.0/7.5 MB 29.2 MB/s eta 0:00:01
#      ---------------------------------- ----- 6.5/7.5 MB 29.7 MB/s eta 0:00:01
#      ---------------------------------------  7.5/7.5 MB 29.9 MB/s eta 0:00:01
#      ---------------------------------------- 7.5/7.5 MB 26.7 MB/s eta 0:00:00
# Collecting asyncio
#   Downloading asyncio-3.4.3-py3-none-any.whl (101 kB)
#      ---------------------------------------- 0.0/101.8 kB ? eta -:--:--
#      ---------------------------------------- 101.8/101.8 kB ? eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.5-cp310-cp310-win_amd64.whl (323 kB)
#      ---------------------------------------- 0.0/323.1 kB ? eta -:--:--
#      ------------------------------------- 323.1/323.1 kB 19.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas->-r ../requirements/requirements.txt (line 1)) (2.8.2)
# Collecting pytz>=2020.1
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#      ---------------------------------------- 0.0/502.3 kB ? eta -:--:--
#      ------------------------------------- 502.3/502.3 kB 32.8 MB/s eta 0:00:00
# Collecting tzdata>=2022.1
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ---------------------------------------- 0.0/341.8 kB ? eta -:--:--
#      ------------------------------------- 341.8/341.8 kB 20.7 MB/s eta 0:00:00
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel->-r ../requirements/requirements.txt (line 3)) (8.3.0)
# Requirement already satisfied: psutil in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel->-r ../requirements/requirements.txt (line 3)) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel->-r ../requirements/requirements.txt (line 3)) (25.1.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel->-r ../requirements/requirements.txt (line 3)) (6.3.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel->-r ../requirements/requirements.txt (line 3)) (0.1.6)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel->-r ../requirements/requirements.txt (line 3)) (8.14.0)
# Requirement already satisfied: nest-asyncio in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel->-r ../requirements/requirements.txt (line 3)) (1.5.7)
# Requirement already satisfied: packaging in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel->-r ../requirements/requirements.txt (line 3)) (23.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel->-r ../requirements/requirements.txt (line 3)) (5.9.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel->-r ../requirements/requirements.txt (line 3)) (1.6.7.post1)
# Requirement already satisfied: comm>=0.1.1 in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel->-r ../requirements/requirements.txt (line 3)) (0.1.4)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipykernel->-r ../requirements/requirements.txt (line 3)) (5.3.1)
# Collecting tomli>=1.0.0
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Collecting pluggy<2.0,>=0.12
#   Downloading pluggy-1.2.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: colorama in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pytest->-r ../requirements/requirements.txt (line 4)) (0.4.6)
# Collecting exceptiongroup>=1.0.0rc8
#   Downloading exceptiongroup-1.1.2-py3-none-any.whl (14 kB)
# Collecting iniconfig
#   Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.42.0-cp310-cp310-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#      -------------------------------- ------- 1.7/2.1 MB 54.2 MB/s eta 0:00:01
#      ---------------------------------------- 2.1/2.1 MB 26.9 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp310-cp310-win_amd64.whl (55 kB)
#      ---------------------------------------- 0.0/55.3 kB ? eta -:--:--
#      ---------------------------------------- 55.3/55.3 kB ? eta 0:00:00
# Collecting pyparsing<3.1,>=2.3.1
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ---------------------------------------- 0.0/98.3 kB ? eta -:--:--
#      ---------------------------------------- 98.3/98.3 kB 5.5 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting pillow>=6.2.0
#   Downloading Pillow-10.0.0-cp310-cp310-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#      ------------------------- -------------- 1.6/2.5 MB 34.0 MB/s eta 0:00:01
#      ---------------------------------------  2.5/2.5 MB 32.0 MB/s eta 0:00:01
#      ---------------------------------------- 2.5/2.5 MB 26.6 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.1.0-cp310-cp310-win_amd64.whl (470 kB)
#      ---------------------------------------- 0.0/470.4 kB ? eta -:--:--
#      ------------------------------------- 470.4/470.4 kB 28.8 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.4.0-cp310-cp310-win_amd64.whl (44 kB)
#      ---------------------------------------- 0.0/44.4 kB ? eta -:--:--
#      ---------------------------------------- 44.4/44.4 kB ? eta 0:00:00
# Collecting charset-normalizer<4.0,>=2.0
#   Downloading charset_normalizer-3.2.0-cp310-cp310-win_amd64.whl (96 kB)
#      ---------------------------------------- 0.0/96.9 kB ? eta -:--:--
#      ---------------------------------------- 96.9/96.9 kB 5.4 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting attrs>=17.3.0
#   Downloading attrs-23.1.0-py3-none-any.whl (61 kB)
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ---------------------------------------- 61.2/61.2 kB 3.2 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp310-cp310-win_amd64.whl (28 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.2-cp310-cp310-win_amd64.whl (61 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB ? eta 0:00:00
# Requirement already satisfied: pygments>=2.4.0 in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements/requirements.txt (line 3)) (2.16.1)
# Requirement already satisfied: pickleshare in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements/requirements.txt (line 3)) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements/requirements.txt (line 3)) (0.19.0)
# Requirement already satisfied: backcall in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements/requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements/requirements.txt (line 3)) (3.0.39)
# Requirement already satisfied: stack-data in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements/requirements.txt (line 3)) (0.6.2)
# Requirement already satisfied: decorator in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements/requirements.txt (line 3)) (5.1.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->-r ../requirements/requirements.txt (line 3)) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->-r ../requirements/requirements.txt (line 3)) (306)
# Requirement already satisfied: six>=1.5 in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil>=2.8.2->pandas->-r ../requirements/requirements.txt (line 1)) (1.16.0)
# Collecting idna>=2.0
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      ---------------------------------------- 0.0/61.5 kB ? eta -:--:--
#      ---------------------------------------- 61.5/61.5 kB ? eta 0:00:00
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r ../requirements/requirements.txt (line 3)) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel->-r ../requirements/requirements.txt (line 3)) (0.2.6)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r ../requirements/requirements.txt (line 3)) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r ../requirements/requirements.txt (line 3)) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\alan_\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r ../requirements/requirements.txt (line 3)) (1.2.0)
# Installing collected packages: pytz, asyncio, tzdata, tomli, pyparsing, pluggy, pillow, numpy, multidict, kiwisolver, iniconfig, idna, frozenlist, fonttools, exceptiongroup, cycler, charset-normalizer, attrs, async-timeout, yarl, pytest, pandas, contourpy, aiosignal, matplotlib, aiohttp
# Successfully installed aiohttp-3.8.5 aiosignal-1.3.1 async-timeout-4.0.3 asyncio-3.4.3 attrs-23.1.0 charset-normalizer-3.2.0 contourpy-1.1.0 cycler-0.11.0 exceptiongroup-1.1.2 fonttools-4.42.0 frozenlist-1.4.0 idna-3.4 iniconfig-2.0.0 kiwisolver-1.4.4 matplotlib-3.7.2 multidict-6.0.4 numpy-1.25.2 pandas-2.0.3 pillow-10.0.0 pluggy-1.2.0 pyparsing-3.0.9 pytest-7.4.0 pytz-2023.3 tomli-2.0.1 tzdata-2023.3 yarl-1.9.2
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: C:\Users\alan_\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Obtaining file:///D:/Users/alan_/Documents/GitHub/software-engineer-technical-test
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Installing collected packages: earthquakes
#   Running setup.py develop for earthquakes
# Successfully installed earthquakes-dev
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: C:\Users\alan_\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Tests

# %%
! chcp 65001
! dir ..\tests\src\earthquakes && pytest
# Out:
# Active code page: 65001
#  Volume in drive D is 新加卷
#  Volume Serial Number is AAD1-CBE2
#
#  Directory of d:\Users\alan_\Documents\GitHub\software-engineer-technical-test\tests\src\earthquakes
#
# 2023/08/11  14:31    <DIR>          .
# 2023/08/11  14:31    <DIR>          ..
# 2023/08/16  16:51               433 test_tools.py
# 2023/08/16  16:47               677 test_usgs_api.py
#                2 File(s)          1,110 bytes
#                2 Dir(s)  279,048,323,072 bytes free
# ============================= test session starts =============================
# platform win32 -- Python 3.10.11, pytest-7.4.0, pluggy-1.2.0
# rootdir: d:\Users\alan_\Documents\GitHub\software-engineer-technical-test
# collected 0 items
#
# ============================ no tests ran in 0.00s ============================

# %% [markdown]
# ---

# %% [markdown]
# # Context
#
# A client asks for an insurance of their asset, located at `(35.025, 25.763)` in Greece.
#
# The client wishes to receive a payout under the following conditions:
#
# + earthquake of magnitude `4.5` or higher within `10km`: full payout
# + earthquake of magnitude `5.5` or higher within `50km`: `75%` payout
# + earthquake of magnitude `6.5` or higher within `200km`: `50%` payout
#
# In the event of aftershocks, a payout can only occur once a year using the maximal value.
#
# ## Example
#
# If in the same year:
#
# * an earthquake of magnitude `6.8` occurs within `200km`
# * **and** an aftershock of magnitude `5.8` occurs within `50km`
#
# the client receives a `75%` payout, and not a `125%` payout.

# %%
! which python
# Out:
# 'which' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import numpy as np
import pandas as pd
from datetime import datetime

from earthquakes.tools import (
    DISTANCE_COLUMN,
    LATITUDE_COLUMN,
    LONGITUDE_COLUMN,
)

# %% [markdown]
# # Earthquake data
#
# The US Geological Service (USGS) provides CSV data through their [API](https://earthquake.usgs.gov/fdsnws/event/1/).
#
# Use it to retrieve earthquake information.
#
# In the module `earthquakes.usgs_api`:
# + Implement the function `get_earthquake_data`,
# + The function will retrieve the earthquake data of the area of interest for the past 200 years,
# + The implementation must use the `urllib` python package,
# + The API request url must be build in a dedicated function `build_api_url`,
# + Tests should be provided for `build_api_url`.
#
# Note: Earthquakes after the 21-10-2021 should not be considered.

# %%
from earthquakes.usgs_api import get_earthquake_data

# %%
# NOTE: Fill me!

latitude = "35.025"
longitude = "25.763"
radius =  "200"
minimum_magnitude = "4.5"

# %%
# NOTE: This request may take significant time (>10s)
earthquake_data = get_earthquake_data(
    latitude=latitude,
    longitude=longitude,
    radius=radius,
    minimum_magnitude=minimum_magnitude,
    end_date=datetime(year=2021, month=10, day=21)
)

# %%
assert isinstance(earthquake_data, pd.DataFrame)
assert len(earthquake_data) == 734

# %% [markdown]
# ## Warning
#
# The next test may fail because USGS regularly updates their earthquake database.
#
# The dataframe obtained should over be similar to that presented bellow.
#
# Please contact us if there is an error.

# %%
expected_earthquake_data = pd.DataFrame([
        ["2021-10-12T09:24:05.099Z", 35.1691, 26.2152, 20.0, 6.4, "mww", np.nan, 19.0, 0.860, 0.46,"us", "us6000ftxu", "2023-08-12T13:32:34.542Z", "4 km SW of Palekastro, Greece", "earthquake", 6.1, 1.8, 0.048, 42.0, "reviewed", "us", "us"],
        ["2021-10-03T14:31:27.622Z", 35.1442, 25.2375, 10.0, 4.6, "mb", np.nan, 119.0, 0.318, 0.64, "us", "us6000fsp1", "2021-12-10T21:14:19.040Z", "2 km W of Arkalochóri, Greece", "earthquake", 5.0, 1.9, 0.165, 13.0, "reviewed", "us", "us"],
        ["2021-09-29T11:54:48.885Z", 35.0268, 25.1561, 10.0, 4.6, "mb", np.nan, 69.0, 0.339, 0.83, "us", "us6000fq3y", "2021-12-04T14:27:58.040Z", "2 km N of Pýrgos, Greece", "earthquake", 5.1, 1.3, 0.068, 64.0, "reviewed", "us", "us"],
        ["2021-09-28T15:13:16.867Z", 35.2054, 25.2791, 10.0, 4.7, "mb", np.nan, 58.0, 0.329, 0.70, "us", "us7000ff84", "2021-12-04T14:30:09.040Z", "1 km N of Thrapsanón, Greece", "earthquake", 6.9, 1.8, 0.067, 73.0, "reviewed", "us", "us"],
        ["2021-09-28T04:48:08.650Z", 35.0817, 25.2018, 10.0, 5.3, "mww", np.nan, 43.0, 0.328, 0.94, "us", "us7000ff36", "2021-12-04T14:30:04.040Z", "9 km SW of Arkalochóri, Greece", "earthquake", 4.5, 1.7, 0.046, 45.0, "reviewed", "us", "us"],
    ],
    columns=['time', 'latitude', 'longitude', 'depth', 'mag', 'magType', 'nst', 'gap', 'dmin', 'rms', 'net', 'id', 'updated', 'place', 'type', 'horizontalError', 'depthError', 'magError', 'magNst', 'status', 'locationSource', 'magSource']
)

# %%
earthquake_data_sample = earthquake_data[
    earthquake_data["time"].isin(expected_earthquake_data["time"])
]

pd.testing.assert_frame_equal(earthquake_data_sample, expected_earthquake_data)

# %% [markdown]
# # Distance
#
# We wish to compute the the historical payouts (i.e. the payouts that would have occurred for the past 200 years).
#
# To compute the historical payouts, we need to know the distance between each earthquake and our client's asset.
#
# The distance between two points on a sphere is the [Haversine distance](https://en.wikipedia.org/wiki/Haversine_formula). In the module `eathquakes.tools`:
# - Implement and test the function `get_haversine_distance`,
# - Use `earthquakes.tools.EARTH_RADIUS` (6378km) as an approximation of the radius of Earth.

# %%
from earthquakes.tools import get_haversine_distance

distances = get_haversine_distance(earthquake_data[LATITUDE_COLUMN], earthquake_data[LONGITUDE_COLUMN], latitude, longitude)

earthquake_data[DISTANCE_COLUMN] = distances

# %% [markdown]
# ## Historical payouts and burning costs
#
# ### Payout
#
# The historical payouts are a map `year -> payout in %`.
#
# eg: `1950: 50` for a payout of `50%` in 1950.
#
# Payouts are NOT given per event, but per year.
#
# This map can take the form of a python `dict` or of a pandas `Series`.
#
# ### Burning cost
#
# The `burning cost` is the average of payouts over a time range.
#
# In this project, the burning cost should be expressed in `%`.
#
# ### Payout structure
#
# The payout structure is:
#
# | Radius | Magnitude | Payout |
# |--------|-----------|--------|
# | 10km   | 4.5       | 100 %  |
# | 50km   | 5.5       |  75 %  |
# | 200km  | 6.5       |  50 %  |
#
# Even though multiple events can happen in a given year, clients can only receive one payout.
#
# In the module `earthquakes.tools`:
# + Implement the functions `compute_payouts` and `compute_burning_cost`,
# + Tests for these functions are not required.
#
# ### Example
#
# A payout `{1950: 50, 1992: 75}` means that we would have paid our client
# + in 1950, for `50%` of the insured amount (called 'limit')
# + in 1992, for `75%` of the limit
#
# The burning cost over the `1922-2021` period would be `1.25%`.
#
# The burning cost over the `1972-2021` period would be `1.5%`.

# %%
from earthquakes.tools import compute_payouts, compute_burning_cost

# %%
# NOTE: Fill me!
data = {
    'Radius': ['10km', '50km', '200km'],
    'Magnitude': [4.5, 5.5, 6.5],
    'Payout': ['100%', '75%', '50%']
}

payout_structure = pd.DataFrame(data)

# %%
payouts = compute_payouts(earthquake_data, payout_structure)

# %%
# Depending on the return type of compute_payouts, the following line needs to be adjusted.
# - pd.Series:
# payout_values = np.array(payouts.values)
# - dict:
payout_values = np.array(list(payouts.values()))
assert np.max(payout_values) > 1
assert np.max(payout_values) <= 100

# %%
burning_cost = compute_burning_cost(payouts, start_year=1952, end_year=2021)

# %%
np.testing.assert_allclose(burning_cost, 10.71, atol=1e-2)

# %%
import matplotlib.pyplot as plt

# %%
years = range(1921, 2021)
plt.plot(
    years, 
    [
        compute_burning_cost(payouts, start_year=start_year, end_year=2021) 
        for start_year in years
    ]
)
plt.gca().invert_xaxis()

# %% [markdown]
# # Large asset portfolio - async requests
#
# Our client also whishes to cover a large amount of properties all over Europe.
#
# In order to speed-up the requests to the USGS API, in the module `earthquakes.usgs_api`:
# - Implement the `async` function `get_earthquake_data_for_multiple_locations`,
# - The implementation should use the `asyncio` and `aiohttp` libraries,
# - The solution should re-use some of the functions already written,
# - Tests are not required for any of the functions.
#
# Note: it is possible that the notebook autoreload feature doesn't work for `async` functions - a kernel restart may be necessary after each modifications.

# %%
import numpy as np
import pandas as pd
from datetime import datetime

from earthquakes.tools import (
    LATITUDE_COLUMN,
    LONGITUDE_COLUMN,
)

# %%
number_of_assets = 10
# NOTE: limiting to number of assets so that the query doesn't take too long.

# %%
random_state = np.random.RandomState(0)

random_values = random_state.random(2*number_of_assets)

latitudes = random_values[::2] * 20 + 35.0
longitudes = random_values[1::2] * 25 + 3.0

# %%
from earthquakes.usgs_api import get_earthquake_data_for_multiple_locations

# %%
# NOTE: Fill me!
assets = list(zip(latitudes, longitudes))

# %%
# NOTE: This request may take significant time (>10s)
earthquake_data = await get_earthquake_data_for_multiple_locations(  # type: ignore
    assets, 
    radius=200, 
    minimum_magnitude=4.5, 
    end_date=datetime(year=2021, month=10, day=21)
)
# Out:
# 10

# %%
assert isinstance(earthquake_data, pd.DataFrame)
assert len(earthquake_data) == 1151
# Out:
# [                        time  latitude  longitude  depth   mag magType    nst  \
# 0   2013-09-08T13:22:12.630Z   45.6097    22.8657    5.0  4.60      mb    NaN
# 1   2002-08-02T09:37:18.220Z   44.7110    21.6200   10.0  4.50      mb  133.0
# 2   2002-05-24T20:42:26.770Z   44.7610    21.6110   10.0  4.70      mb  227.0
# 3   1996-03-24T09:13:28.030Z   45.6230    21.0230   22.6  4.80      mb    NaN
# 4   1994-10-13T23:31:27.510Z   45.4930    21.0040   10.0  4.70      mb    NaN
# 5   1992-12-19T09:34:06.120Z   45.5610    20.9500   22.6  4.60      mb    NaN
# 6   1992-03-02T20:33:21.360Z   45.9520    21.6300   25.6  4.60      mb    NaN
# 7   1991-12-02T08:49:40.280Z   45.4980    21.1150    9.0  5.50      mw    NaN
# 8   1991-10-28T00:21:32.460Z   44.2650    21.4560   67.1  4.80      mb    NaN
# 9   1991-08-15T01:34:33.650Z   45.4850    21.2860   10.0  4.50      md    NaN
# 10  1991-08-14T23:36:00.780Z   45.4780    21.1580   10.0  4.70      mb    NaN
# 11  1991-08-02T00:51:04.790Z   45.2620    21.0870   25.9  4.70      md    NaN
# 12  1991-07-19T01:27:32.060Z   45.3120    21.0530   10.0  5.10      mw    NaN
# 13  1991-07-18T11:56:30.650Z   44.8880    22.4070   11.6  5.60      mw    NaN
# 14  1991-07-12T10:42:21.210Z   45.3640    21.0570   10.7  5.60      mw    NaN
# 15  1978-09-26T16:47:33.100Z   47.1610    18.9620   10.0  4.50      ml    NaN
# 16  1978-06-22T02:33:24.000Z   46.7160    21.0550   10.0  4.60      mb    NaN
# 17  1974-04-17T01:31:33.900Z   45.9720    21.1410   33.0  5.60      mb    NaN
# 18  1973-11-29T16:47:33.800Z   45.4790    18.7040   33.0  4.80      mb    NaN
# 19  1959-05-27T20:38:28.220Z   45.6960    20.9800   15.0  5.28      mw    NaN
# 20  1936-09-06T04:48:57.500Z   45.7090    20.9750   10.0  5.17      mw    NaN
# 21  1927-05-15T03:12:01.900Z   44.2420    20.7820   15.0  5.56      mw    NaN
# 22  1911-07-08T01:01:57.100Z   46.7230    20.4000   15.0  5.75      mw    NaN
#
#     gap  dmin   rms  ...                   updated  \
# 0   NaN   NaN  0.75  ...  2022-07-25T21:49:02.307Z
# 1   NaN   NaN  1.12  ...  2014-11-07T01:16:11.310Z
# 2   NaN   NaN  1.21  ...  2020-09-18T18:53:16.032Z
# 3   NaN   NaN  1.10  ...  2014-11-07T01:00:08.274Z
# 4   NaN   NaN  1.20  ...  2014-11-07T00:56:31.006Z
# 5   NaN   NaN  1.20  ...  2014-11-07T00:52:03.421Z
# 6   NaN   NaN  0.90  ...  2014-11-07T00:50:12.826Z
# 7   NaN   NaN  1.10  ...  2022-04-28T18:56:37.588Z
# 8   NaN   NaN  1.10  ...  2014-11-07T00:49:28.041Z
# 9   NaN   NaN  1.20  ...  2014-11-07T00:49:05.433Z
# 10  NaN   NaN  1.40  ...  2014-11-07T00:49:05.412Z
# 11  NaN   NaN  1.20  ...  2014-11-07T00:49:01.833Z
# 12  NaN   NaN  1.20  ...  2022-04-28T19:07:52.969Z
# 13  NaN   NaN  1.20  ...  2022-04-28T19:07:50.310Z
# 14  NaN   NaN  1.30  ...  2022-04-28T19:07:37.411Z
# 15  NaN   NaN   NaN  ...  2014-11-06T23:21:52.562Z
# 16  NaN   NaN   NaN  ...  2020-08-26T19:51:28.577Z
# 17  NaN   NaN   NaN  ...  2020-08-25T23:43:34.844Z
# 18  NaN   NaN   NaN  ...  2014-11-06T23:21:21.626Z
# 19  NaN   NaN   NaN  ...  2022-05-09T19:32:32.175Z
# 20  NaN   NaN   NaN  ...  2022-05-09T17:10:47.351Z
# 21  NaN   NaN   NaN  ...  2022-04-25T23:04:41.417Z
# 22  NaN   NaN   NaN  ...  2022-04-25T20:37:50.908Z
#
#                                      place        type horizontalError  \
# 0   1 km WSW of General Berthelot, Romania  earthquake             NaN
# 1         4 km SW of Moldova Nou?, Romania  earthquake             NaN
# 2            2 km ESE of Pojejena, Romania  earthquake             NaN
# 3            3 km NW of Peciu Nou, Romania  earthquake             NaN
# 4             6 km SSE of Giulv?z, Romania  earthquake             NaN
# 5             3 km WNW of Giulv?z, Romania  earthquake             NaN
# 6               5 km ESE of Bogda, Romania  earthquake             NaN
# 7              1 km SW of Ciacova, Romania  earthquake             NaN
# 8              30 km ENE of Lapovo, Serbia  earthquake             NaN
# 9              4 km ENE of Voiteg, Romania  earthquake             NaN
# 10              2 km NE of Ghilad, Romania  earthquake             NaN
# 11        4 km ENE of Velika Greda, Serbia  earthquake             NaN
# 12           7 km ENE of Stari Lec, Serbia  earthquake             NaN
# 13    1 km NNW of B?ile Herculane, Romania  earthquake             NaN
# 14             2 km S of Livezile, Romania  earthquake             NaN
# 15              1 km E of Ráckeve, Hungary  earthquake             NaN
# 16          5 km NW of Békéscsaba, Hungary  earthquake             NaN
# 17             4 km S of M?n??tur, Romania  earthquake             NaN
# 18          2 km ESE of Antunovac, Croatia  earthquake             NaN
# 19              6 km ESE of Cenei, Romania  earthquake             NaN
# 20                5 km E of Cenei, Romania  earthquake             NaN
# 21        19 km ESE of Aran?elovac, Serbia  earthquake             NaN
# 22     6 km NW of Fábiánsebestyén, Hungary  earthquake             NaN
#
#    depthError  magError  magNst    status  locationSource  magSource
# 0         4.7     0.137     NaN  reviewed          us_buc         us
# 1         NaN       NaN    11.0  reviewed              us         us
# 2         NaN       NaN    66.0  reviewed              us         us
# 3         9.0       NaN     2.0  reviewed              us         us
# 4         NaN       NaN     4.0  reviewed              us         us
# 5         4.1       NaN     8.0  reviewed              us         us
# 6         3.3       NaN     7.0  reviewed              us         us
# 7         1.9       NaN     NaN  reviewed              us        hrv
# 8         7.0       NaN    23.0  reviewed              us         us
# 9         NaN       NaN     NaN  reviewed              us        tri
# 10        NaN       NaN     6.0  reviewed              us         us
# 11        5.3       NaN     NaN  reviewed              us        tri
# 12        NaN       NaN     NaN  reviewed              us        hrv
# 13        NaN       NaN     NaN  reviewed              us        hrv
# 14        NaN       NaN     NaN  reviewed              us        hrv
# 15        NaN       NaN     NaN  reviewed              us        tri
# 16        NaN       NaN     NaN  reviewed              us         us
# 17        NaN       NaN     NaN  reviewed              us         us
# 18        NaN       NaN     NaN  reviewed              us         us
# 19        6.3     0.360     NaN  reviewed       iscgemsup  iscgemsup
# 20        6.3     0.200     NaN  reviewed       iscgemsup  iscgemsup
# 21        5.6     0.280     NaN  reviewed          iscgem     iscgem
# 22       25.0     0.350     NaN  reviewed          iscgem     iscgem
#
# [23 rows x 22 columns],                         time  latitude  longitude  depth   mag magType    nst  \
# 0   2021-08-16T23:58:56.595Z   45.4755    16.2341   10.0  4.60      mb    NaN
# 1   2021-01-06T17:01:43.679Z   45.4322    16.2422   10.0  4.70     mwr    NaN
# 2   2020-12-29T11:29:05.687Z   45.3665    16.2696   10.0  4.50      mb    NaN
# 3   2020-12-29T11:23:46.151Z   45.3879    16.2421   10.0  4.90      mb    NaN
# 4   2020-12-29T11:19:54.762Z   45.4244    16.2573   10.0  6.40     mww    NaN
# 5   2020-12-28T05:28:07.913Z   45.4413    16.1877   10.0  4.80     mwr    NaN
# 6   2020-03-22T06:01:20.688Z   45.9104    15.9786   10.0  4.60     mwr    NaN
# 7   2020-03-22T05:24:03.700Z   45.9072    15.9697   10.0  5.30     mww    NaN
# 8   2019-03-07T19:07:52.916Z   46.3834    17.3539   10.0  4.50      mb    NaN
# 9   2003-07-21T13:15:57.920Z   47.1610    14.3330   10.0  4.70      ml  204.0
# 10  2001-07-01T01:48:59.080Z   47.7500    16.1370   10.0  5.10      md   61.0
# 11  2000-07-11T10:56:03.900Z   47.9650    16.3600   10.0  5.00      ml  106.0
# 12  2000-07-11T02:49:47.600Z   48.0130    16.4190   10.0  5.30      ml  182.0
# 13  1996-01-09T01:07:21.530Z   47.9570    16.3820   10.0  4.50      ml    NaN
# 14  1994-12-03T12:28:48.800Z   47.7160    16.1660   12.2  4.60      ml    NaN
# 15  1993-06-01T19:51:10.920Z   46.1660    16.4670   30.1  4.90      mb    NaN
# 16  1993-05-29T08:43:11.680Z   45.5610    15.2070   15.2  5.10      mb    NaN
# 17  1990-09-03T10:48:33.130Z   45.9150    15.8730   20.2  4.80      mb    NaN
# 18  1985-08-15T05:29:17.310Z   47.0240    18.0130    8.6  4.50      ml    NaN
# 19  1985-08-15T04:28:46.970Z   47.0450    18.0540   10.0  5.20      mw    NaN
# 20  1984-03-11T11:55:31.750Z   45.8670    15.4830   10.0  4.60      ml    NaN
# 21  1983-04-14T14:52:12.950Z   47.6960    15.1030   10.0  4.50      mb    NaN
# 22  1982-03-16T13:52:23.560Z   46.1670    16.2590   14.4  4.70      mb    NaN
# 23  1978-09-26T16:47:33.100Z   47.1610    18.9620   10.0  4.50      ml    NaN
# 24  1977-07-16T13:13:29.600Z   46.2900    14.2930    6.0  4.60      mb    NaN
# 25  1974-06-20T17:08:27.300Z   45.9650    15.5290   47.0  4.50      mb    NaN
# 26  1973-06-12T21:02:56.900Z   47.5690    15.3320    5.0  4.80      mb    NaN
# 27  1973-06-11T03:15:39.300Z   46.1930    16.0930   11.0  4.50      mb    NaN
# 28  1972-04-16T10:10:06.230Z   47.8040    16.0530   15.0  5.14      mw    NaN
# 29  1963-05-19T10:00:03.960Z   46.1450    14.6980   10.0  5.31      mw    NaN
# 30  1958-03-19T16:04:02.570Z   46.8970    14.2540   15.0  5.04      mw    NaN
# 31  1939-09-18T00:14:34.810Z   47.7150    16.0330   15.0  5.49      mw    NaN
# 32  1938-11-08T03:11:38.170Z   47.6360    16.2310   15.0  5.44      mw    NaN
# 33  1938-03-27T11:16:26.840Z   46.2770    16.9510   10.0  5.90      mw    NaN
# 34  1936-10-03T15:48:34.880Z   47.1470    14.8490   10.0  5.45      mw    NaN
# 35  1935-10-21T11:07:12.750Z   45.3610    17.2350   15.0  5.28      mw    NaN
# 36  1930-03-05T23:55:52.440Z   48.0430    17.6020   15.0  5.24      mw    NaN
# 37  1927-10-08T19:49:02.130Z   47.8850    16.4690   15.0  5.45      mw    NaN
# 38  1927-07-25T20:35:33.020Z   47.7500    15.5820   15.0  5.43      mw    NaN
# 39  1921-05-04T17:35:38.340Z   48.4710    17.6610   15.0  5.22      mw    NaN
# 40  1917-01-29T08:22:56.840Z   45.8000    15.6690   15.0  5.77      mw    NaN
# 41  1909-10-08T09:59:11.780Z   45.4640    16.0900   15.0  5.96      mw    NaN
# 42  1906-01-02T04:26:27.250Z   45.3860    16.5210   15.0  5.79      mw    NaN
#
#      gap   dmin   rms  ...                   updated  \
# 0   21.0  1.064  0.69  ...  2021-10-29T14:46:23.040Z
# 1   24.0  0.955  0.75  ...  2022-07-23T13:43:21.442Z
# 2   56.0  0.895  0.74  ...  2021-03-06T23:20:17.040Z
# 3   68.0  0.924  0.93  ...  2021-03-06T23:20:16.040Z
# 4   13.0  0.941  0.75  ...  2023-03-29T20:18:48.464Z
# 5   13.0  0.988  0.56  ...  2022-07-23T13:39:39.229Z
# 6   14.0  0.787  0.46  ...  2020-06-06T20:54:05.040Z
# 7   12.0  0.794  0.59  ...  2023-02-17T14:06:55.780Z
# 8   33.0  0.409  1.29  ...  2022-04-04T07:10:09.993Z
# 9   16.8    NaN  1.15  ...  2014-11-07T01:19:16.261Z
# 10   NaN    NaN  0.72  ...  2014-11-07T01:13:11.665Z
# 11   NaN    NaN  1.18  ...  2014-11-07T01:10:35.266Z
# 12   NaN    NaN  1.26  ...  2020-09-15T21:29:25.635Z
# 13   NaN    NaN  1.00  ...  2014-11-07T00:59:38.121Z
# 14   NaN    NaN  1.30  ...  2014-11-07T00:56:54.400Z
# 15   NaN    NaN  1.40  ...  2022-04-28T18:08:10.651Z
# 16   NaN    NaN  1.20  ...  2014-11-07T00:53:05.531Z
# 17   NaN    NaN  1.20  ...  2014-11-07T00:47:04.386Z
# 18   NaN    NaN  1.20  ...  2014-11-07T00:37:01.073Z
# 19   NaN    NaN  1.30  ...  2022-04-27T22:40:28.463Z
# 20   NaN    NaN  1.30  ...  2014-11-07T00:34:37.638Z
# 21   NaN    NaN  1.20  ...  2014-11-07T00:32:58.973Z
# 22   NaN    NaN  1.10  ...  2020-08-26T21:58:47.829Z
# 23   NaN    NaN   NaN  ...  2014-11-06T23:21:52.562Z
# 24   NaN    NaN   NaN  ...  2021-10-20T18:03:49.726Z
# 25   NaN    NaN   NaN  ...  2020-08-25T23:46:50.316Z
# 26   NaN    NaN   NaN  ...  2014-11-06T23:21:13.252Z
# 27   NaN    NaN   NaN  ...  2014-11-06T23:21:13.219Z
# 28   NaN    NaN   NaN  ...  2022-04-26T20:52:31.582Z
# 29   NaN    NaN   NaN  ...  2022-05-09T19:23:19.482Z
# 30   NaN    NaN   NaN  ...  2022-05-09T19:42:24.648Z
# 31   NaN    NaN   NaN  ...  2022-04-25T20:49:36.162Z
# 32   NaN    NaN   NaN  ...  2022-04-25T21:00:55.575Z
# 33   NaN    NaN   NaN  ...  2022-04-25T20:53:36.499Z
# 34   NaN    NaN   NaN  ...  2022-04-25T21:27:38.520Z
# 35   NaN    NaN   NaN  ...  2022-05-09T17:17:05.621Z
# 36   NaN    NaN   NaN  ...  2022-05-09T17:33:29.598Z
# 37   NaN    NaN   NaN  ...  2022-04-25T23:10:16.833Z
# 38   NaN    NaN   NaN  ...  2022-05-09T17:43:18.981Z
# 39   NaN    NaN   NaN  ...  2022-05-09T17:58:23.745Z
# 40   NaN    NaN   NaN  ...  2022-04-25T23:58:00.945Z
# 41   NaN    NaN   NaN  ...  2022-04-25T20:38:41.888Z
# 42   NaN    NaN   NaN  ...  2022-04-25T20:36:34.425Z
#
#                                                 place        type  \
# 0                        6 km NW of Petrinja, Croatia  earthquake
# 1                         3 km W of Petrinja, Croatia  earthquake
# 2                       8 km SSW of Petrinja, Croatia  earthquake
# 3                        6 km SW of Petrinja, Croatia  earthquake
# 4                       2 km WSW of Petrinja, Croatia  earthquake
# 5                         8 km W of Petrinja, Croatia  earthquake
# 6                    6 km E of Gornja Bistra, Croatia  earthquake
# 7                    5 km E of Gornja Bistra, Croatia  earthquake
# 8                        3 km SSW of Böhönye, Hungary  earthquake
# 9                     3 km WNW of Niederwölz, Austria  earthquake
# 10                     1 km NNW of Breitenau, Austria  earthquake
# 11               3 km ESE of Oberwaltersdorf, Austria  earthquake
# 12                       2 km W of Moosbrunn, Austria  earthquake
# 13                   1 km WNW of Weigelsdorf, Austria  earthquake
# 14                          1 km W of Pitten, Austria  earthquake
# 15  Slovenia-Hungary-Croatia border region,earthquake
# 16                      1 km SE of ?rnomelj, Slovenia  earthquake
# 17                  1 km ENE of Donja Bistra, Croatia  earthquake
# 18                 1 km SSW of Balatonalmádi, Hungary  earthquake
# 19                 2 km ENE of Balatonalmádi, Hungary  earthquake
# 20         5 km ENE of Kostanjevica na Krki, Slovenia  earthquake
# 21                    10 km ENE of Wildalpen, Austria  earthquake
# 22                     5 km WSW of Remetinec, Croatia  earthquake
# 23                         1 km E of Ráckeve, Hungary  earthquake
# 24                         2 km NW of Naklo, Slovenia  earthquake
# 25                        2 km ENE of Krško, Slovenia  earthquake
# 26                                 Austria,earthquake
# 27                        3 km SSW of Ivanec, Croatia  earthquake
# 28        1 km N of Willendorf am Steinfelde, Austria  earthquake
# 29          2 km S of Lukovica pri Domžalah, Slovenia  earthquake
# 30                           3 km NW of Gurk, Austria  earthquake
# 31                       0 km WSW of Ternitz, Austria  earthquake
# 32                      3 km SSE of Bromberg, Austria  earthquake
# 33                        7 km ESE of Legrad, Croatia  earthquake
# 34                    0 km S of Kleinlobming, Austria  earthquake
# 35                          8 km SE of Lipik, Croatia  earthquake
# 36                5 km N of Dunajská Streda, Slovakia  earthquake
# 37           Austria-Hungary border region,earthquake
# 38                      10 km NE of Mürzsteg, Austria  earthquake
# 39                    8 km WNW of Leopoldov, Slovakia  earthquake
# 40                            3 km N of Rude, Croatia  earthquake
# 41                      7 km ESE of Pokupsko, Croatia  earthquake
# 42                         4 km WNW of Sunja, Croatia  earthquake
#
#    horizontalError depthError  magError  magNst    status  locationSource  \
# 0              4.3       1.90     0.066    69.0  reviewed              us
# 1              3.7       1.80     0.041    57.0  reviewed              us
# 2              2.3       1.90     0.382     2.0  reviewed              us
# 3              3.6       1.90     0.177    10.0  reviewed              us
# 4              4.4       1.80     0.033    89.0  reviewed              us
# 5              3.5       1.60     0.046    45.0  reviewed              us
# 6              4.2       1.80     0.044    49.0  reviewed              us
# 7              3.7       1.80     0.035    79.0  reviewed              us
# 8              5.7       1.60     0.539     1.0  reviewed              us
# 9              NaN        NaN       NaN     NaN  reviewed              us
# 10             NaN        NaN       NaN     NaN  reviewed              us
# 11             NaN        NaN       NaN     NaN  reviewed              us
# 12             NaN        NaN       NaN     NaN  reviewed              us
# 13             NaN        NaN       NaN     NaN  reviewed              us
# 14             NaN       2.80       NaN     NaN  reviewed              us
# 15             3.0        NaN    35.000     NaN        us              us
# 16             NaN       3.10       NaN     2.0  reviewed              us
# 17             NaN       2.40       NaN    18.0  reviewed              us
# 18             NaN       2.80       NaN     NaN  reviewed              us
# 19             NaN        NaN       NaN     NaN  reviewed              us
# 20             NaN        NaN       NaN     NaN  reviewed              us
# 21             NaN        NaN       NaN     6.0  reviewed              us
# 22             NaN       1.90       NaN     5.0  reviewed              us
# 23             NaN        NaN       NaN     NaN  reviewed              us
# 24             NaN        NaN       NaN     NaN  reviewed              us
# 25             NaN        NaN       NaN     NaN  reviewed              us
# 26             NaN        NaN       NaN     NaN        us              us
# 27             NaN        NaN       NaN     NaN  reviewed              us
# 28             NaN       7.10     0.340     NaN  reviewed          iscgem
# 29             NaN       5.30     0.260     NaN  reviewed       iscgemsup
# 30             NaN       5.40     0.200     NaN  reviewed       iscgemsup
# 31             NaN       7.00     0.200     NaN  reviewed          iscgem
# 32             NaN       7.00     0.240     NaN  reviewed          iscgem
# 33             NaN       6.70     0.200     NaN  reviewed          iscgem
# 34             NaN       4.50     0.200     NaN  reviewed          iscgem
# 35             NaN      23.10     0.320     NaN  reviewed       iscgemsup
# 36             NaN       2.20     0.200     NaN  reviewed       iscgemsup
# 37             3.7       0.25       NaN     NaN    iscgem          iscgem
# 38             NaN       1.60     0.200     NaN  reviewed       iscgemsup
# 39             NaN       4.10     0.200     NaN  reviewed       iscgemsup
# 40             NaN       7.30     0.200     NaN  reviewed          iscgem
# 41             NaN       5.30     0.200     NaN  reviewed          iscgem
# 42             NaN       4.90     0.410     NaN  reviewed          iscgem
#
#     magSource
# 0          us
# 1          us
# 2          us
# 3          us
# 4          us
# 5          us
# 6          us
# 7          us
# 8          us
# 9        zamg
# 10        vie
# 11        cll
# 12        brg
# 13        cll
# 14        grf
# 15       None
# 16         us
# 17         us
# 18        grf
# 19        hrv
# 20        grf
# 21         us
# 22         us
# 23        tri
# 24         us
# 25         us
# 26       None
# 27         us
# 28     iscgem
# 29  iscgemsup
# 30  iscgemsup
# 31     iscgem
# 32     iscgem
# 33     iscgem
# 34     iscgem
# 35  iscgemsup
# 36  iscgemsup
# 37       None
# 38  iscgemsup
# 39  iscgemsup
# 40     iscgem
# 41     iscgem
# 42     iscgem
#
# [43 rows x 22 columns],                          time  latitude  longitude  depth   mag magType  nst  \
# 0    2021-10-06T19:57:33.511Z   43.6811    16.8584  10.00  4.90      mb  NaN
# 1    2019-11-26T09:19:25.856Z   43.2235    17.9118  10.00  5.30     mww  NaN
# 2    2019-11-02T14:11:34.527Z   44.3854    17.5423  10.00  4.70      mb  NaN
# 3    2019-08-30T13:01:36.004Z   44.6411    18.5250   7.26  4.80      mb  NaN
# 4    2018-11-13T13:47:50.980Z   41.9723    19.2987  10.00  4.80      mb  NaN
# ..                        ...       ...        ...    ...   ...     ...  ...
# 208  1907-05-18T00:59:58.850Z   43.5890    16.7480  15.00  5.22      mw  NaN
# 209  1905-08-12T21:26:29.830Z   41.8120    19.6890  15.00  5.35      mw  NaN
# 210  1905-06-03T05:10:40.470Z   42.1240    19.4110  15.00  5.93      mw  NaN
# 211  1905-06-01T21:47:01.440Z   42.1440    19.2050  15.00  5.59      mw  NaN
# 212  1905-06-01T04:42:11.110Z   42.0920    19.2480  15.00  6.55      mw  NaN
#
#       gap   dmin   rms  ...                   updated  \
# 0    16.0  1.092  1.16  ...  2021-12-10T21:14:15.040Z
# 1    24.0  1.270  0.86  ...  2020-12-29T14:18:53.242Z
# 2    39.0  2.153  1.25  ...  2020-01-18T20:00:55.040Z
# 3    29.0  2.203  0.90  ...  2020-07-25T18:08:57.451Z
# 4    28.0  0.448  0.99  ...  2019-01-30T18:36:21.040Z
# ..    ...    ...   ...  ...                       ...
# 208   NaN    NaN   NaN  ...  2022-05-09T15:19:28.657Z
# 209   NaN    NaN   NaN  ...  2022-05-09T15:23:18.212Z
# 210   NaN    NaN   NaN  ...  2022-05-09T15:19:19.446Z
# 211   NaN    NaN   NaN  ...  2022-04-25T20:38:34.457Z
# 212   NaN    NaN   NaN  ...  2022-04-25T20:36:26.209Z
#
#                                            place        type horizontalError  \
# 0                       10 km E of Otok, Croatia  earthquake             4.2
# 1     4 km SSE of Blagaj, Bosnia and Herzegovina  earthquake             5.5
# 2       15 km N of Turbe, Bosnia and Herzegovina  earthquake             4.4
# 3     6 km NNW of Mramor, Bosnia and Herzegovina  earthquake             5.4
# 4                  7 km NE of Ulcinj, Montenegro  earthquake             5.2
# ..                                           ...         ...             ...
# 208                   3 km SSE of Trilj, Croatia  earthquake             NaN
# 209                    4 km NE of Lezhë, Albania  earthquake             NaN
# 210  Montenegro-Albania border region,earthquake                         6.5
# 211             7 km NE of Stari Bar, Montenegro  earthquake             NaN
# 212              9 km E of Stari Bar, Montenegro  earthquake             NaN
#
#     depthError  magError  magNst     status  locationSource  magSource
# 0         1.80     0.059    89.0   reviewed              us         us
# 1         1.80     0.058    29.0   reviewed              us         us
# 2         1.80     0.050   123.0   reviewed              us         us
# 3         4.50     0.035   252.0   reviewed              us         us
# 4         1.90     0.071    62.0   reviewed              us         us
# ..         ...       ...     ...        ...             ...        ...
# 208      11.10     0.200     NaN   reviewed       iscgemsup  iscgemsup
# 209       6.50     0.260     NaN   reviewed       iscgemsup  iscgemsup
# 210       0.79       NaN     NaN  iscgemsup       iscgemsup       None
# 211       5.80     0.550     NaN   reviewed          iscgem     iscgem
# 212       5.80     0.200     NaN   reviewed          iscgem     iscgem
#
# [213 rows x 22 columns],                         time  latitude  longitude  depth   mag magType    nst  \
# 0   2020-05-01T11:01:39.470Z   42.2322    24.8892  10.00  4.50      mb    NaN
# 1   2017-11-26T19:01:32.730Z   42.7258    24.2869  10.94  4.50      mb    NaN
# 2   2012-01-01T23:57:19.400Z   45.0300    23.5400   6.00  4.50      mb   97.0
# 3   2002-04-05T13:14:01.310Z   42.0400    24.9110  26.80  4.70      mb  135.0
# 4   2001-08-13T14:26:11.880Z   42.6020    26.5070  10.00  4.60      mb  198.0
# 5   1999-11-23T00:47:51.760Z   42.0650    25.1650   3.80  4.50      ml    NaN
# 6   1998-12-11T15:09:19.530Z   42.2530    25.2700  10.00  4.70      mb    NaN
# 7   1993-05-23T17:19:23.650Z   45.3650    25.5120  22.10  4.70      mb    NaN
# 8   1986-12-18T17:16:14.790Z   43.3050    26.0660   6.10  4.50      mb    NaN
# 9   1986-12-07T14:17:09.560Z   43.2740    25.9120  20.50  5.60      mw    NaN
# 10  1986-02-21T05:39:55.950Z   43.3210    25.9680  20.50  5.40      mw    NaN
# 11  1982-08-27T09:58:55.940Z   43.7180    26.0680  33.00  4.70      mb    NaN
# 12  1977-05-25T11:59:23.200Z   45.3430    26.0170  38.00  4.60      mb    NaN
# 13  1975-02-08T08:21:18.000Z   45.3150    25.9960  23.00  4.60      mb    NaN
# 14  1969-04-12T20:38:42.130Z   45.2980    25.0720  14.00  5.18      mw    NaN
# 15  1960-01-04T12:52:00.460Z   45.0690    26.8290  40.00  5.36      mw    NaN
# 16  1932-05-27T10:42:01.650Z   44.3240    24.9430  15.00  5.45      mw    NaN
# 17  1928-04-28T17:59:07.040Z   42.0630    24.8520  15.00  5.62      mw    NaN
# 18  1928-04-25T09:25:56.130Z   42.0640    25.7940  15.00  5.84      mw    NaN
# 19  1928-04-19T22:40:18.400Z   42.1210    25.6270  15.00  5.22      mw    NaN
# 20  1928-04-19T01:09:58.770Z   42.3320    25.3140  15.00  5.12      mw    NaN
# 21  1928-04-18T23:14:54.690Z   42.4390    25.2990  15.00  5.75      mw    NaN
# 22  1928-04-18T19:22:56.900Z   42.3510    25.0440  10.00  7.10      mw    NaN
# 23  1928-04-14T10:23:46.930Z   42.3530    25.5990  15.00  5.58      mw    NaN
# 24  1928-04-14T09:00:00.020Z   42.3510    25.6410  10.00  7.10      mw    NaN
# 25  1913-06-14T09:33:28.430Z   43.1520    25.7590  15.00  6.69      mw    NaN
#
#      gap   dmin   rms  ...                   updated  \
# 0   25.0  1.189  0.91  ...  2021-04-06T19:20:34.953Z
# 1   41.0  0.704  1.25  ...  2018-02-20T09:06:03.040Z
# 2   26.6    NaN   NaN  ...  2015-03-24T01:24:30.030Z
# 3    NaN    NaN  0.82  ...  2020-09-18T18:49:00.253Z
# 4    NaN    NaN  1.16  ...  2020-09-18T18:29:47.136Z
# 5    NaN    NaN   NaN  ...  2014-11-07T01:08:59.666Z
# 6    NaN    NaN  1.15  ...  2014-11-07T01:06:38.526Z
# 7    NaN    NaN  1.20  ...  2014-11-07T00:53:03.689Z
# 8    NaN    NaN  1.30  ...  2014-11-07T00:39:30.257Z
# 9    NaN    NaN  1.20  ...  2022-04-27T21:57:30.508Z
# 10   NaN    NaN  1.20  ...  2022-04-27T22:24:23.943Z
# 11   NaN    NaN  1.10  ...  2014-11-07T00:31:47.553Z
# 12   NaN    NaN   NaN  ...  2014-11-06T23:21:42.092Z
# 13   NaN    NaN   NaN  ...  2014-11-06T23:21:28.783Z
# 14   NaN    NaN   NaN  ...  2022-04-26T22:08:34.864Z
# 15   NaN    NaN   NaN  ...  2022-05-09T19:27:35.033Z
# 16   NaN    NaN   NaN  ...  2022-04-25T22:04:43.451Z
# 17   NaN    NaN   NaN  ...  2022-04-25T22:51:59.276Z
# 18   NaN    NaN   NaN  ...  2022-04-25T22:51:55.586Z
# 19   NaN    NaN   NaN  ...  2022-05-09T17:39:59.325Z
# 20   NaN    NaN   NaN  ...  2022-05-09T17:39:53.922Z
# 21   NaN    NaN   NaN  ...  2022-04-25T22:51:38.769Z
# 22   NaN    NaN   NaN  ...  2022-04-25T22:51:33.431Z
# 23   NaN    NaN   NaN  ...  2022-04-25T22:51:16.441Z
# 24   NaN    NaN   NaN  ...  2022-04-25T22:51:11.079Z
# 25   NaN    NaN   NaN  ...  2022-04-26T00:09:13.528Z
#
#                                   place        type horizontalError  \
# 0         6 km SW of Rakovski, Bulgaria  earthquake             5.0
# 1             2 km S of Anton, Bulgaria  earthquake             4.3
# 2             4 km W of Albeni, Romania  earthquake             NaN
# 3       4 km NE of Asenovgrad, Bulgaria  earthquake             NaN
# 4           13 km N of Yambol, Bulgaria  earthquake             NaN
# 5         5 km SW of Parvomay, Bulgaria  earthquake             NaN
# 6          7 km NW of Chirpan, Bulgaria  earthquake             NaN
# 7           3 km WNW of Sinaia, Romania  earthquake             NaN
# 8      11 km NE of Strazhitsa, Bulgaria  earthquake             NaN
# 9       6 km NW of Strazhitsa, Bulgaria  earthquake             NaN
# 10       9 km N of Strazhitsa, Bulgaria  earthquake             NaN
# 11        9 km ENE of Ivanovo, Bulgaria  earthquake             NaN
# 12             2 km SW of Slon, Romania  earthquake             NaN
# 13  1 km E of M?neciu-Ungureni, Romania  earthquake             NaN
# 14          0 km S of Voine?ti, Romania  earthquake             NaN
# 15           2 km NW of Maxenu, Romania  earthquake             NaN
# 16      3 km WNW of Zâmbreasca, Romania  earthquake             NaN
# 17     5 km NNW of Asenovgrad, Bulgaria  earthquake             NaN
# 18    4 km NW of Simeonovgrad, Bulgaria  earthquake             NaN
# 19   8 km NNE of Dimitrovgrad, Bulgaria  earthquake             NaN
# 20         14 km N of Chirpan, Bulgaria  earthquake             NaN
# 21   19 km SSE of Pavel Banya, Bulgaria  earthquake             NaN
# 22          3 km W of Brezovo, Bulgaria  earthquake             NaN
# 23   9 km SSW of Stara Zagora, Bulgaria  earthquake             NaN
# 24     9 km S of Stara Zagora, Bulgaria  earthquake             NaN
# 25     5 km NNE of Lyaskovets, Bulgaria  earthquake             NaN
#
#    depthError  magError  magNst    status  locationSource  magSource
# 0         1.9     0.070    60.0  reviewed              us         us
# 1         5.4     0.205     7.0  reviewed              us         us
# 2         NaN       NaN    16.0  reviewed             buc         us
# 3         2.0       NaN    76.0  reviewed              us         us
# 4         NaN       NaN    58.0  reviewed              us         us
# 5         NaN       NaN     NaN  reviewed             the        the
# 6         NaN       NaN    40.0  reviewed              us         us
# 7         3.3       NaN    61.0  reviewed              us         us
# 8         3.0       NaN     7.0  reviewed              us         us
# 9         2.4       NaN     NaN  reviewed              us        hrv
# 10        3.0       NaN     NaN  reviewed              us        hrv
# 11        NaN       NaN     4.0  reviewed              us         us
# 12        NaN       NaN     NaN  reviewed              us         us
# 13        NaN       NaN     NaN  reviewed              us         us
# 14        7.3     0.200     NaN  reviewed          iscgem     iscgem
# 15       13.0     0.710     NaN  reviewed       iscgemsup  iscgemsup
# 16       25.0     0.250     NaN  reviewed          iscgem     iscgem
# 17        8.0     0.200     NaN  reviewed          iscgem     iscgem
# 18        4.2     0.200     NaN  reviewed          iscgem     iscgem
# 19        5.6     0.200     NaN  reviewed       iscgemsup  iscgemsup
# 20       25.0     0.200     NaN  reviewed       iscgemsup  iscgemsup
# 21       25.0     0.200     NaN  reviewed          iscgem     iscgem
# 22       25.0     0.400     NaN  reviewed          iscgem     iscgem
# 23       25.0     0.200     NaN  reviewed          iscgem     iscgem
# 24       25.0     0.400     NaN  reviewed          iscgem     iscgem
# 25        7.1     0.320     NaN  reviewed          iscgem     iscgem
#
# [26 rows x 22 columns], None,                         time  latitude  longitude  depth  mag magType  nst  \
# 0   2020-07-08T05:18:59.767Z   51.5656    16.2485    5.0  5.0      mb  NaN
# 1   2019-07-05T18:41:00.107Z   51.5296    16.1693   10.0  4.6      mb  NaN
# 2   2019-01-29T12:53:44.980Z   51.5720    16.1672   10.0  4.9      mb  NaN
# 3   2018-09-15T16:35:15.950Z   51.5640    16.1679    5.0  4.7      mb  NaN
# 4   2018-07-20T03:31:30.670Z   51.5725    16.1770   10.0  4.9      mb  NaN
# ..                       ...       ...        ...    ...  ...     ...  ...
# 61  1982-08-01T02:25:02.900Z   51.6310    16.1810   10.0  4.7      mb  NaN
# 62  1982-01-16T11:15:58.950Z   51.6100    16.2810   10.0  4.8      mb  NaN
# 63  1981-04-10T04:59:47.710Z   51.6270    16.1820   10.0  4.8      mb  NaN
# 64  1980-12-21T05:51:16.100Z   51.6330    16.2590   10.0  4.8      mb  NaN
# 65  1977-03-24T07:32:30.500Z   51.3210    15.7740   33.0  5.0      mb  NaN
#
#      gap   dmin   rms  ...                   updated  \
# 0   40.0  1.971  0.83  ...  2022-08-08T23:34:59.869Z
# 1   29.0  1.960  0.75  ...  2020-07-10T17:43:39.276Z
# 2   29.0  1.998  1.13  ...  2022-08-08T11:53:53.909Z
# 3   34.0  1.992  1.17  ...  2020-07-10T17:17:46.306Z
# 4   13.0  1.997  0.98  ...  2020-07-10T17:13:16.952Z
# ..   ...    ...   ...  ...                       ...
# 61   NaN    NaN  1.20  ...  2020-08-26T22:08:06.647Z
# 62   NaN    NaN  0.80  ...  2020-08-26T21:53:00.547Z
# 63   NaN    NaN  0.80  ...  2020-08-26T21:31:18.271Z
# 64   NaN    NaN   NaN  ...  2020-08-26T21:23:44.704Z
# 65   NaN    NaN   NaN  ...  2020-08-26T01:23:34.013Z
#
#                             place        type horizontalError depthError  \
# 0         6 km N of Rudna, Poland  earthquake             4.7        1.8
# 1       6 km WNW of Rudna, Poland  earthquake             4.1        1.8
# 2     3 km S of Gr?bocice, Poland  earthquake             2.2        1.9
# 3     3 km S of Gr?bocice, Poland  earthquake             5.1        1.9
# 4   3 km SSE of Gr?bocice, Poland  earthquake             5.8        1.8
# ..                            ...         ...             ...        ...
# 61  3 km NNE of Gr?bocice, Poland  earthquake             NaN        NaN
# 62    7 km E of Gr?bocice, Poland  earthquake             NaN        NaN
# 63  3 km NNE of Gr?bocice, Poland  earthquake             NaN        NaN
# 64  7 km ENE of Gr?bocice, Poland  earthquake             NaN        NaN
# 65     4 km S of Gromadka, Poland  earthquake             NaN        NaN
#
#     magError  magNst    status  locationSource magSource
# 0      0.038   224.0  reviewed              us        us
# 1      0.058    92.0  reviewed              us        us
# 2      0.050   124.0  reviewed              us        us
# 3      0.060    85.0  reviewed              us        us
# 4      0.047   145.0  reviewed              us        us
# ..       ...     ...       ...             ...       ...
# 61       NaN     2.0  reviewed              us        us
# 62       NaN     7.0  reviewed              us        us
# 63       NaN     1.0  reviewed              us        us
# 64       NaN     NaN  reviewed              us        us
# 65       NaN     NaN  reviewed              us        us
#
# [66 rows x 22 columns],                          time  latitude  longitude   depth   mag magType  nst  \
# 0    2021-04-09T18:36:46.739Z   45.8044    26.6269   77.38  4.50      mb  NaN
# 1    2020-04-24T22:04:16.273Z   45.9075    27.4877   10.00  4.90      mb  NaN
# 2    2020-01-31T01:26:47.718Z   45.7414    26.6516  122.12  4.80     mww  NaN
# 3    2019-09-03T11:52:52.396Z   45.5087    26.2188  113.27  4.60      mb  NaN
# 4    2019-08-30T07:00:04.357Z   45.7323    26.6439  134.63  4.50      mb  NaN
# ..                        ...       ...        ...     ...   ...     ...  ...
# 124  1940-10-22T06:37:01.060Z   45.5900    26.3830  130.00  6.63      mw  NaN
# 125  1934-03-29T20:06:50.220Z   45.8610    26.6240  105.00  6.72      mw  NaN
# 126  1929-11-01T06:57:24.700Z   45.8150    26.5850  155.00  5.79      mw  NaN
# 127  1919-04-18T06:20:10.420Z   45.7240    25.1150   35.00  5.42      mw  NaN
# 128  1916-01-26T07:38:03.810Z   45.8610    24.7120   15.00  6.36      mw  NaN
#
#       gap   dmin   rms  ...                   updated  \
# 0    57.0  0.571  0.88  ...  2021-08-26T00:27:20.233Z
# 1    11.0  1.158  0.66  ...  2020-12-27T16:44:42.557Z
# 2    21.0  0.555  0.90  ...  2021-05-25T21:53:40.668Z
# 3    16.0  0.193  0.86  ...  2019-11-30T19:37:29.040Z
# 4    56.0  0.546  1.05  ...  2022-08-08T15:50:38.354Z
# ..    ...    ...   ...  ...                       ...
# 124   NaN    NaN   NaN  ...  2022-04-26T19:38:48.481Z
# 125   NaN    NaN   NaN  ...  2022-04-26T15:36:53.653Z
# 126   NaN    NaN   NaN  ...  2022-04-25T22:45:47.937Z
# 127   NaN    NaN   NaN  ...  2022-05-09T18:01:37.576Z
# 128   NaN    NaN   NaN  ...  2022-04-26T00:01:38.395Z
#
#                                   place        type horizontalError  \
# 0           7 km WNW of Paltin, Romania  earthquake             5.7
# 1         1 km ESE of Ungureni, Romania  earthquake             4.5
# 2        5 km NW of Nereju Mic, Romania  earthquake             5.6
# 3    4 km NW of Lunca Jari?tei, Romania  earthquake             6.4
# 4        5 km NW of Nereju Mic, Romania  earthquake             6.8
# ..                                  ...         ...             ...
# 124   12 km NNW of Gura Teghii, Romania  earthquake             NaN
# 125        6 km SW of P?ule?ti, Romania  earthquake             NaN
# 126        10 km WNW of Paltin, Romania  earthquake             NaN
# 127     6 km SW of ?inca Veche, Romania  earthquake             NaN
# 128           1 km SE of Bruiu, Romania  earthquake             NaN
#
#     depthError  magError  magNst    status  locationSource  magSource
# 0          6.7     0.112    25.0  reviewed              us         us
# 1          1.8     0.031   320.0  reviewed              us         us
# 2          3.2     0.080    15.0  reviewed              us         us
# 3          6.9     0.062    79.0  reviewed              us         us
# 4          6.2     0.150    13.0  reviewed              us         us
# ..         ...       ...     ...       ...             ...        ...
# 124        6.2     0.400     NaN  reviewed          iscgem     iscgem
# 125       31.7     0.400     NaN  reviewed          iscgem     iscgem
# 126       31.7     0.400     NaN  reviewed          iscgem     iscgem
# 127        7.3     0.390     NaN  reviewed       iscgemsup  iscgemsup
# 128       25.0     0.310     NaN  reviewed          iscgem     iscgem
#
# [129 rows x 22 columns],                          time  latitude  longitude  depth   mag magType  nst  \
# 0    2021-07-19T19:21:28.085Z   36.6973     5.6209   10.0  4.60      mb  NaN
# 1    2021-04-01T14:33:33.714Z   36.4139     7.1942   10.0  4.80      mb  NaN
# 2    2021-03-25T02:37:14.465Z   36.8311     5.1854   10.0  4.60      mb  NaN
# 3    2021-03-24T23:23:54.166Z   36.8879     5.2734   10.0  4.50      mb  NaN
# 4    2021-03-18T00:33:27.553Z   36.8702     5.2300   10.0  4.70      mb  NaN
# ..                        ...       ...        ...    ...   ...     ...  ...
# 117  1946-02-12T02:43:25.350Z   35.5990     4.8070   15.0  5.91      mw  NaN
# 118  1943-04-16T11:43:15.670Z   36.0830     4.5240   15.0  5.66      mw  NaN
# 119  1931-08-15T13:52:02.970Z   36.1620     3.7200   15.0  4.84      mw  NaN
# 120  1924-03-16T10:17:29.620Z   35.3520     6.2240   15.0  5.77      mw  NaN
# 121  1910-06-24T13:26:59.730Z   35.8880     3.7540   15.0  6.46      mw  NaN
#
#       gap   dmin   rms  ...                   updated  \
# 0    69.0  3.162  0.84  ...  2022-08-09T06:18:36.529Z
# 1    89.0  1.871  1.04  ...  2021-06-08T17:59:44.040Z
# 2    52.0  3.144  0.66  ...  2022-08-09T04:23:39.357Z
# 3    68.0  3.105  0.48  ...  2021-06-02T15:22:42.040Z
# 4    63.0  3.114  0.55  ...  2021-05-26T22:08:44.040Z
# ..    ...    ...   ...  ...                       ...
# 117   NaN    NaN   NaN  ...  2022-04-26T18:53:31.013Z
# 118   NaN    NaN   NaN  ...  2022-04-26T19:11:02.373Z
# 119   NaN    NaN   NaN  ...  2022-05-09T17:31:13.577Z
# 120   NaN    NaN   NaN  ...  2022-04-25T23:29:57.804Z
# 121   NaN    NaN   NaN  ...  2022-04-25T20:31:36.075Z
#
#                                      place        type horizontalError  \
# 0               18 km SW of Jijel, Algeria  earthquake             6.4
# 1             21 km WSW of Guelma, Algeria  earthquake             5.3
# 2              12 km NE of Bejaïa, Algeria  earthquake             6.8
# 3              northern Algeria,earthquake         6.3             1.9
# 4              18 km NE of Bejaïa, Algeria  earthquake             6.3
# ..                                     ...         ...             ...
# 117           26 km ESE of M’Sila, Algeria  earthquake             NaN
# 118           6 km E of Mansourah, Algeria  earthquake             NaN
# 119            northern Algeria,earthquake                        25.0
# 120  14 km SSW of Tazoult-Lambese, Algeria  earthquake             NaN
# 121          1 km W of Sidi Aïssa, Algeria  earthquake             NaN
#
#     depthError  magError  magNst     status  locationSource magSource
# 0        1.900     0.054   103.0   reviewed              us        us
# 1        1.900     0.074    56.0   reviewed              us        us
# 2        1.900     0.114    23.0   reviewed              us        us
# 3        0.127    18.000     NaN         us              us      None
# 4        1.800     0.070    62.0   reviewed              us        us
# ..         ...       ...     ...        ...             ...       ...
# 117      4.600     0.480     NaN   reviewed          iscgem    iscgem
# 118     10.000     0.650     NaN   reviewed          iscgem    iscgem
# 119      0.200       NaN     NaN  iscgemsup       iscgemsup      None
# 120     25.000     0.200     NaN   reviewed          iscgem    iscgem
# 121      5.200     0.200     NaN   reviewed          iscgem    iscgem
#
# [122 rows x 22 columns],                          time  latitude  longitude  depth   mag magType  nst  \
# 0    2021-10-03T14:31:27.622Z   35.1442    25.2375   10.0  4.60      mb  NaN
# 1    2021-09-29T11:54:48.885Z   35.0268    25.1561   10.0  4.60      mb  NaN
# 2    2021-09-28T15:13:16.867Z   35.2054    25.2791   10.0  4.70      mb  NaN
# 3    2021-09-28T04:48:08.650Z   35.0817    25.2018   10.0  5.30     mww  NaN
# 4    2021-09-27T20:10:01.502Z   35.1951    25.2253   10.0  4.70      mb  NaN
# ..                        ...       ...        ...    ...   ...     ...  ...
# 530  1910-02-18T05:09:12.690Z   35.8090    23.9920   60.0  5.85      mw  NaN
# 531  1908-06-23T14:41:31.410Z   36.7680    24.6970   15.0  5.52      mw  NaN
# 532  1908-06-23T14:14:13.520Z   36.6560    24.2240   15.0  5.45      mw  NaN
# 533  1908-05-17T12:30:50.780Z   34.9870    23.8840   35.0  6.06      mw  NaN
# 534  1906-06-17T01:13:17.920Z   34.5540    24.6620   15.0  5.34      mw  NaN
#
#        gap   dmin   rms  ...                   updated  \
# 0    119.0  0.318  0.64  ...  2021-12-10T21:14:19.040Z
# 1     69.0  0.339  0.83  ...  2021-12-04T14:27:58.040Z
# 2     58.0  0.329  0.70  ...  2021-12-04T14:30:09.040Z
# 3     43.0  0.328  0.94  ...  2021-12-04T14:30:04.040Z
# 4     51.0  0.289  0.70  ...  2021-12-04T14:29:59.040Z
# ..     ...    ...   ...  ...                       ...
# 530    NaN    NaN   NaN  ...  2022-04-25T20:31:06.919Z
# 531    NaN    NaN   NaN  ...  2022-05-09T15:20:45.492Z
# 532    NaN    NaN   NaN  ...  2022-05-09T15:20:39.941Z
# 533    NaN    NaN   NaN  ...  2022-04-25T20:29:39.549Z
# 534    NaN    NaN   NaN  ...  2022-05-09T15:24:32.393Z
#
#                               place        type horizontalError depthError  \
# 0     2 km W of Arkalochóri, Greece  earthquake             5.0        1.9
# 1          2 km N of Pýrgos, Greece  earthquake             5.1        1.3
# 2      1 km N of Thrapsanón, Greece  earthquake             6.9        1.8
# 3    9 km SW of Arkalochóri, Greece  earthquake             4.5        1.7
# 4      5 km W of Thrapsanón, Greece  earthquake             5.5        1.8
# ..                              ...         ...             ...        ...
# 530  32 km N of Agía Marína, Greece  earthquake             NaN       28.5
# 531    11 km ESE of Kímolos, Greece  earthquake             NaN        6.7
# 532      20 km WSW of Mílos, Greece  earthquake             NaN       35.5
# 533      25 km NW of Kastrí, Greece  earthquake             NaN       12.4
# 534      58 km S of Tympáki, Greece  earthquake             NaN       15.9
#
#      magError  magNst    status  locationSource  magSource
# 0       0.165    13.0  reviewed              us         us
# 1       0.068    64.0  reviewed              us         us
# 2       0.067    73.0  reviewed              us         us
# 3       0.046    45.0  reviewed              us         us
# 4       0.056    95.0  reviewed              us         us
# ..        ...     ...       ...             ...        ...
# 530     0.200     NaN  reviewed          iscgem     iscgem
# 531     0.270     NaN  reviewed       iscgemsup  iscgemsup
# 532     0.230     NaN  reviewed       iscgemsup  iscgemsup
# 533     0.340     NaN  reviewed          iscgem     iscgem
# 534     0.200     NaN  reviewed       iscgemsup  iscgemsup
#
# [535 rows x 22 columns],                        time  latitude  longitude  depth  mag magType  nst  \
# 0  2021-09-23T03:17:58.019Z   48.9703    25.9793  15.84  4.5      mb  NaN
#
#     gap   dmin   rms  ...                   updated  \
# 0  42.0  1.425  0.98  ...  2021-12-03T15:01:52.040Z
#
#                            place        type horizontalError depthError  \
# 0  9 km ESE of Zavodske, Ukraine  earthquake             3.7        4.1
#
#    magError  magNst    status  locationSource magSource
# 0     0.111    25.0  reviewed              us        us
#
# [1 rows x 22 columns]]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[45], line 2
#       1 print(earthquake_data)
# ----> 2 assert isinstance(earthquake_data, pd.DataFrame)
#       3 assert len(earthquake_data) == 1151
#
# AssertionError:
